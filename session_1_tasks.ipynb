# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanashreeBalar/Data-Science-Practice/blob/main/session_1_tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task : Session 1
# Solve these questions own your own and try to test yourself what you have learned in the session.
#
# Happy Learning!

# %% [markdown]
# ### Q1 :- Print the given strings as per stated format.
#
# **Given strings**:
# ```
# "Data" "Science" "Mentorship" "Program"
# "By" "CampusX"
# ```
# **Output**:
# ```
# Data-Science-Mentorship-Program-started-By-CampusX
# ```
#
# Concept- [Seperator and End]

# %%
# Write your code here
print("Data","Science","Mentorship","Program","By","CampusX",sep="-")
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %% [markdown]
# ### Q2:- Write a program that will convert celsius value to fahrenheit.

# %%
# Write your code here
c = 32
print("fahrenheit = ",c * 9/5 + 32)
# Out:
# fahrenheit =  89.6

# %% [markdown]
# ### Q3:- Take 2 numbers as input from the user.Write a program to swap the numbers without using any special python syntax.

# %%
# Write your code here
a = int(input("enter num1 : "))
b = int(input("enter num2 : "))
print("a = ",a,"b = ",b)
print("a = ",b,"b = ",a)
# Out:
# enter num1 : 5
# enter num2 : 4
# a =  5 b =  4
# a =  4 b =  5

# %% [markdown]
# ### Q4:- Write a program to find the euclidean distance between two coordinates.Take both the coordinates from the user as input.

# %%
# Write your code here
a1 = int(input("enter a1 coordinate : "))
a2 = int(input("enter a2 coordinate : "))
b1 = int(input("enter b1 coordinate : "))
b2 = int(input("enter b2 coordinate : "))

d = ((a2-a1)**2 + (b2-b1)**2)**0.5
print(d)
# Out:
# enter a1 coordinate : 2
# enter a2 coordinate : 3
# enter b1 coordinate : 1
# enter b2 coordinate : 4
# 3.1622776601683795

# %% [markdown]
# ### Q5:- Write a program to find the simple interest when the value of principle,rate of interest and time period is provided by the user.

# %%
# Write your code here
p = int(input("enter a principle : "))
i = int(input("enter a interest : "))
t = int(input("enter a period : "))

print("simple interest = ",(p*i*t)/100)
# Out:
# enter a principle : 20000
# enter a interest : 12
# enter a period : 1
# simple interest =  2400.0

# %% [markdown]
# ### Q6:- Write a program that will tell the number of dogs and chicken are there when the user will provide the value of total heads and legs.
#
# For example:
# Input:
# heads -> 4
# legs -> 12
# <br>
# Output:
# dogs -> 2
# chicken -> 2

# %%
# Write your code here
h = int(input("enter number of heads :"))
l = int(input("enter number of legs :"))

d = (l-2*h)/2
c = h - d

print("dog :",int(d) , "chicken :",int(c))
# Out:
# enter number of heads :4
# enter number of legs :12
# dog : 2 chicken : 2

# %% [markdown]
# ### Q7:- Write a program to find the sum of squares of first n natural numbers where n will be provided by the user.

# %%
# Write your code here
n = int(input("enter a natural num :"))

sum_of_squares = (n * (n+1) * (2*n+1))/6
print("sum of squares of ",n," = ",sum_of_squares)
# Out:
# enter a natural num :5
# sum of squares of  5  =  55.0

# %% [markdown]
# ### Q8:- Given the first 2 terms of an Arithmetic Series.Find the Nth term of the series. Assume all inputs are provided by the user.

# %%
# Write your code here
a = int(input("Enter first term: "))
b = int(input("Enter second term: "))
n = int(input("Enter n: "))

d = b - a
nth_term = a + (n - 1) * d

print("Nth term of the series:", nth_term)
# Out:
# Enter first term: 5
# Enter second term: 3
# Enter n: 6
# Nth term of the series: -5

# %% [markdown]
# ### Q9:- Given 2 fractions, find the sum of those 2 fractions.Take the numerator and denominator values of the fractions from the user.

# %%
# Write your code here
n1 = int(input("Enter numerator of first fraction: "))
d1 = int(input("Enter denominator of first fraction: "))
n2 = int(input("Enter numerator of second fraction: "))
d2 = int(input("Enter denominator of second fraction: "))

# Sum of fractions
num = n1 * d2 + n2 * d1
den = d1 * d2

print("Sum of fractions =", num, "/", den)
# Out:
# Enter numerator of first fraction: 3
# Enter denominator of first fraction: 4
# Enter numerator of second fraction: 2
# Enter denominator of second fraction: 5
# Sum of fractions = 23 / 20

# %% [markdown]
# ### Q10:- Given the height, width and breadth of a milk tank, you have to find out how many glasses of milk can be obtained? Assume all the inputs are provided by the user.
#
#
#
# Input:<br>
# Dimensions of the milk tank<br>
# H = 20cm, L = 20cm, B = 20cm
# <br><br>
# Dimensions of the glass<br>
# h = 3cm, r = 1cm

# %%
# Write your code here
H = int(input("Enter height of tank (cm): "))
L = int(input("Enter length of tank (cm): "))
B = int(input("Enter breadth of tank (cm): "))

# Glass dimensions
h = int(input("Enter height of glass (cm): "))
r = int(input("Enter radius of glass (cm): "))

# Volumes
tank_volume = H * L * B
glass_volume = 3.14 * r * r * h

# Number of glasses
glasses = tank_volume // glass_volume

print("Number of glasses of milk =", int(glasses))
# Out:
# Enter height of tank (cm): 20
# Enter length of tank (cm): 20
# Enter breadth of tank (cm): 20
# Enter height of glass (cm): 3
# Enter radius of glass (cm): 1
# Number of glasses of milk = 849
